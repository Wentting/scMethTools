# %%
# !pip install -U chunkdot
# Out:
# ...
#   Obtaining dependency information for chunkdot from https://files.pythonhosted.org/packages/04/27/c34f186995d5bb94972cad2abc421038fe03e87948c1b5c802bcabd9f2bb/chunkdot-0.2.8-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for numba<0.58.0,>=0.57.0 from https://files.pythonhosted.org/packages/bc/43/a4a058fc1b58aa523b69141b98e51edf795fd0ff20e690dc8c1ed654c7fd/numba-0.57.1-cp39-cp39-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for llvmlite<0.41,>=0.40.0dev0 from https://files.pythonhosted.org/packages/e7/fb/a7430788e80cff1ec512ba6ca6d2159c0ed6293530b0d502d171e299872f/llvmlite-0.40.1-cp39-cp39-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for numpy<2.0,>=1.23 from https://files.pythonhosted.org/packages/63/38/6cc19d6b8bfa1d1a459daf2b3fe325453153ca7019976274b6f33d8b5663/numpy-1.24.4-cp39-cp39-win_amd64.whl.metadata
# ...

# %%
from scipy import sparse
from chunkdot import cosine_similarity_top_k

embeddings = sparse.rand(1000, 100, density=0.005)
# most dissimilar items using 20GB
cosine_similarity_top_k(embeddings, top_k=-50, max_memory=4E9)
# Out:
# <1000x1000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 50000 stored elements in Compressed Sparse Row format>

# %%
embeddings
# Out:
# <1000x100 sparse matrix of type '<class 'numpy.float64'>'
# 	with 500 stored elements in COOrdinate format>

# %%
x = cosine_similarity_top_k(embeddings, top_k=20, max_memory=4E9)

# %%
print(x)
# Out:
#   (0, 326)	0.0
#   (0, 605)	0.8995906839003236
#   (0, 330)	0.0
#   (0, 856)	1.0
#   (0, 331)	0.0
#   (0, 985)	1.0
#   (0, 332)	0.0
#   (0, 333)	0.0
#   (0, 85)	0.9999999999999999
#   (0, 334)	0.0
#   (0, 335)	0.0
#   (0, 336)	0.0
#   (0, 556)	0.9777740878069181
#   (0, 337)	0.0
#   (0, 162)	1.0
#   (0, 338)	0.0
#   (0, 339)	0.0
#   (0, 0)	1.0
#   (0, 340)	0.0
#   (0, 329)	0.0
#   (1, 315)	0.0
#   (1, 317)	0.0
#   (1, 318)	0.0
#   (1, 316)	0.0
#   (1, 327)	0.0
#   :	:
#   (998, 339)	0.0
#   (998, 340)	0.0
#   (998, 341)	0.0
#   (998, 342)	0.0
#   (998, 328)	0.0
#   (999, 315)	0.0
#   (999, 317)	0.0
#   (999, 318)	0.0
#   (999, 316)	0.0
#   (999, 327)	0.0
#   (999, 329)	0.0
#   (999, 330)	0.0
#   (999, 331)	0.0
#   (999, 332)	0.0
#   (999, 333)	0.0
#   (999, 334)	0.0
#   (999, 335)	0.0
#   (999, 336)	0.0
#   (999, 337)	0.0
#   (999, 338)	0.0
#   (999, 339)	0.0
#   (999, 340)	0.0
#   (999, 341)	0.0
#   (999, 342)	0.0
#   (999, 328)	0.0

# %%
import matplotlib.pylab as plt

# %%
plt.spy(x,markersize=1)
